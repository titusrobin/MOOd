# %%
# pip install pillow torch tqdm
# Out:
# Requirement already satisfied: pillow in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (10.2.0)
# Requirement already satisfied: torch in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: tqdm in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (4.66.5)
# Requirement already satisfied: filelock in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch) (3.12.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# WARNING: Error parsing dependencies of textract: .* suffix can only be used with `==` or `!=` operators
#     extract-msg (<=0.29.*)
#                  ~~~~~~~^
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (8.3.20)
# Requirement already satisfied: numpy>=1.23.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (1.24.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (4.7.0)
# Requirement already satisfied: pillow>=7.1.2 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (1.13.0)
# Requirement already satisfied: torch>=1.8.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (2.2.1)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from ultralytics) (2.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.12.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2023.10.0)
# Requirement already satisfied: six>=1.5 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/jiayizhou/miniconda3/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# WARNING: Error parsing dependencies of textract: .* suffix can only be used with `==` or `!=` operators
#     extract-msg (<=0.29.*)
#                  ~~~~~~~^
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from nuscenes.nuscenes import NuScenes
from nuscenes.utils.splits import create_splits_scenes
from PIL import Image
import torch
from ultralytics import YOLO
import numpy as np
import json
from tqdm import tqdm


class NuScenesConesDataset:
    def __init__(self, dataroot, version="v1.0-mini", split="train"):
        self.nusc = NuScenes(version=version, dataroot=dataroot, verbose=True)
        self.split = split
        self.scenes = create_splits_scenes()[split]

    def prepare_dataset(self, output_dir):
        """
        Prepare dataset in YOLO format:
        - images/train/
        - images/val/
        - labels/train/
        - labels/val/
        """
        os.makedirs(os.path.join(output_dir, "images", self.split), exist_ok=True)
        os.makedirs(os.path.join(output_dir, "labels", self.split), exist_ok=True)

        # Track all annotations
        for scene in tqdm(self.scenes):
            # start with first scene
            scene_rec = self.nusc.scene[0]
            first_sample_token = scene_rec["first_sample_token"]
            sample = self.nusc.get("sample", first_sample_token)

            while sample:
                # Get camera images
                cam_front_data = self.nusc.get(
                    "sample_data", sample["data"]["CAM_FRONT"]
                )

                # Get image
                img_path = os.path.join(self.nusc.dataroot, cam_front_data["filename"])
                img = Image.open(img_path)

                # Get annotations
                annotations = []
                for ann_token in sample["anns"]:
                    ann_rec = self.nusc.get("sample_annotation", ann_token)
                    if ann_rec["category_name"] == "movable_object.traffic_cone":
                        # Get 2D bbox in image coordinates
                        bbox = self.nusc.get_box(ann_rec["token"])
                        corners_2d = self.nusc.box_to_keypoints(
                            cam_front_data["token"], bbox
                        )

                        # Convert to YOLO format (normalized coordinates)
                        x_min, y_min = np.min(corners_2d, axis=0)
                        x_max, y_max = np.max(corners_2d, axis=0)

                        width = img.width
                        height = img.height

                        # YOLO format: <class> <x_center> <y_center> <width> <height>
                        x_center = ((x_min + x_max) / 2) / width
                        y_center = ((y_min + y_max) / 2) / height
                        bbox_width = (x_max - x_min) / width
                        bbox_height = (y_max - y_min) / height

                        annotations.append(
                            f"0 {x_center} {y_center} {bbox_width} {bbox_height}"
                        )

                # Save image and labels
                img_filename = os.path.basename(cam_front_data["filename"])
                label_filename = os.path.splitext(img_filename)[0] + ".txt"

                img.save(os.path.join(output_dir, "images", self.split, img_filename))
                with open(
                    os.path.join(output_dir, "labels", self.split, label_filename), "w"
                ) as f:
                    f.write("\n".join(annotations))

                # Move to next sample
                if sample["next"] == "":
                    break
                sample = self.nusc.get("sample", sample["next"])

# %%
def create_data_yaml(output_dir):
    """Create data.yaml file for YOLO training"""
    data_yaml = {
        "path": output_dir,
        "train": "images/train",
        "val": "images/val",
        "names": {0: "traffic_cone"},
    }

    with open(os.path.join(output_dir, "data.yaml"), "w") as f:
        json.dump(data_yaml, f, indent=2)

# %%
# Set paths
dataroot = "../data/v1.0-mini"  # Replace with your NuScenes data path
output_dir = "../output"  # Replace with your desired output path

# Prepare training data
print("Preparing training data...")
train_dataset = NuScenesConesDataset(dataroot, split="train")
train_dataset.prepare_dataset(output_dir)

# Prepare validation data
print("Preparing validation data...")
val_dataset = NuScenesConesDataset(dataroot, split="val")
val_dataset.prepare_dataset(output_dir)

# Create data.yaml
print("Creating data.yaml...")
create_data_yaml(output_dir)
# Out:
# Preparing training data...
# ======
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 0.455 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 0.1 seconds.
# ======
#   5%|▌         | 35/700 [00:48<15:22,  1.39s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 8
#       6 print("Preparing training data...")
#       7 train_dataset = NuScenesConesDataset(dataroot, split="train")
# ----> 8 train_dataset.prepare_dataset(output_dir)
#      10 # Prepare validation data
#      11 print("Preparing validation data...")
#
# Cell In[15], line 77, in NuScenesConesDataset.prepare_dataset(self, output_dir)
#      74 img_filename = os.path.basename(cam_front_data["filename"])
#      75 label_filename = os.path.splitext(img_filename)[0] + ".txt"
# ---> 77 img.save(os.path.join(output_dir, "images", self.split, img_filename))
#      78 with open(
#      79     os.path.join(output_dir, "labels", self.split, label_filename), "w"
#      80 ) as f:
#      81     f.write("\n".join(annotations))
#
# File ~/miniconda3/lib/python3.11/site-packages/PIL/Image.py:2439, in Image.save(self, fp, format, **params)
#    2436         fp = builtins.open(filename, "w+b")
#    2438 try:
# -> 2439     save_handler(self, fp, filename)
#    2440 except Exception:
#    2441     if open_fp:
#
# File ~/miniconda3/lib/python3.11/site-packages/PIL/JpegImagePlugin.py:824, in _save(im, fp, filename)
#     819 else:
#     820     # The EXIF info needs to be written as one block, + APP1, + one spare byte.
#     821     # Ensure that our buffer is big enough. Same with the icc_profile block.
#     822     bufsize = max(bufsize, len(exif) + 5, len(extra) + 1)
# --> 824 ImageFile._save(im, fp, [("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize)
#
# File ~/miniconda3/lib/python3.11/site-packages/PIL/ImageFile.py:538, in _save(im, fp, tile, bufsize)
#     536     fh = fp.fileno()
#     537     fp.flush()
# --> 538     _encode_tile(im, fp, tile, bufsize, fh)
#     539 except (AttributeError, io.UnsupportedOperation) as exc:
#     540     _encode_tile(im, fp, tile, bufsize, None, exc)
#
# File ~/miniconda3/lib/python3.11/site-packages/PIL/ImageFile.py:565, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     562                 break
#     563     else:
#     564         # slight speedup: compress to real file object
# --> 565         errcode = encoder.encode_to_file(fh, bufsize)
#     566 if errcode < 0:
#     567     raise _get_oserror(errcode, encoder=True) from exc
#
# KeyboardInterrupt:

# %%
def train_yolo(data_yaml_path):
    """Train YOLO model"""
    # Load a pretrained model
    model = YOLO("yolov8n.pt")

    # Train the model
    results = model.train(
        data=data_yaml_path,
        epochs=100,
        imgsz=640,
        batch=16,
        name="traffic_cone_detector",
    )

    return model

# %%
# Train model
print("Training YOLO model...")
model = train_yolo(os.path.join(output_dir, "data.yaml"))

print("Training complete!")
